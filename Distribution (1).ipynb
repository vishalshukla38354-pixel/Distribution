# %% [markdown]
# 1. Simulate 30 rolls with =RANDBETWEEN(1,6). What is the probability of rolling a 3 exactly 5 times? (Hint: Use
# BINOM.DIST)
#
# - Given:
#
# - Number of trials = 30
# - Probability of getting 3 = 1/6
# - Number of successes = 5
#
# Use Binominal Distribution:
#
# P(X = 5) = (30/5)  (1/6)5 (5/6)25
#
# **Excel Formula** :
# =
# =BINOM.DIST(5,30,1/6,FALSE)
#
# **Answer**
#
# Probability = 0.1715(17.15%)

# %% [markdown]
# 2. Generate 100 values in Excel using the continuous uniform distribution RAND() and plot a histogram.
# Describe the shape of the distribution.
#
# - 1. In cell A1 type:
#
# Excel formula
#
#  =RAND()
#
#  2. Drag the FOrmula down to A100.
#
#  3. Select the data ➡ Insert ➡ Histogram Chart.
#
#  **Shape of Distribution**
#
#  The histogram will appear **approximately flat/rectangular**, because every value between 0 and 1 has nearly equal probability in a uniform distribution.

# %% [markdown]
# 3. A dataset has a mean of 50 and a standard deviation of 5. What percentage of values lie between 45 and
# 55 if the data follows a normal distribution?
#
#  - Given:
#
#  - Mean = 50
#
# - Standerad devviation = 5
#
# Find Z-scores:
#
#             z = x − μ /σ
#
#    For 45:
#
#    z= 45-50/5 = **-1**
#
# For 55:
#
# z = 55-50/5 = **1**
#
# In a normal distribution , about **68%** of values lie between μ - 1σ and μ + 1σ
#
# **Answer**
#
#  Approximately **68%**
#
#
#  4. What is the concept of standardization (z-score), and why is it important in data analysis? Explain the
# formula and how standardization transforms a dataset.
#
# - Standardization converts data into a common scale with:
#
# - Mean = 0
#
# - Standerd deviation = 1
#
# **Formula**
#
#      z = x − μ /σ
#   Where:
#
#   - x = data value
#   - μ = mean
#   - σ = standard deviation
#
#    **Importance**
#
#   - Helps compare different darasets
#
#   - Used in machine learning
#   - Detects outliers
#   - Makes analysis easier.
#
#  5. What is Kurtosis and their type?
#
#  Ans:
#
#   Kurtosis mearsures the **peakedness and tail heaviness** of a distribution.
#
#   **Types**
#   =
#   1. **Mesokurtic**
#
#   * Normal distribution
#   - Moderate peak
#
#   2. **Leptokurtic**
#
#   - High peak
#   - Heavy tails
#   3. **Platykurtic**
#   - Flat peak
#   - Light tails
#
#
#
# 6. Explain why the uniform distribution is a good model for the outcome of rolling a fair die.
#
# Ans:
#
#  Afair die has 6 outcomes:
#
#  1,2,3,4,5,6
#
#  Each outcome has equal probability:
#  P(X = x) = 1/6
#
#  So the die follows a **discrete uniform distribution**.
#
#
# Q7. Use Excel to compute the probability of getting at least 8 successes in 15 trials with success probability 0.5
#
# Ans:
# =
#
#  Given:
#
#  - n= 15
#  - p = 0.5
#
#  "At least 8" means:
#
#  P(X ≥ 8)
#
# Excel Formula
# -
#
# =1-BINOM.DIST(7,15,0.5,TRUE)
#
# Answer:
#
#  Prbability = 0.5001(50.01%)
#
#
# Q8. How does log transformation help in stabilizing variance and making data more normally distributed?
#
# Ans:
#
# log transformation:
#
# Y= log(X)
#
#
# Benefits
# -
# - Reduces skewness
# - Stabilizes variance
# - Make data more normally distributed
# - Reduces impact of extream values
# - Improves statistical analysis and machine learning models
#
# Example
# -
#
# data:
#
#  10,100,1000
#
#
#  After log:
#
#  1,2,3
#
#  The spread becomes smaller and easier to analyze.
